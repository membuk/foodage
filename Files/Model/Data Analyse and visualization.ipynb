# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/content/Veriler.csv"
df = pd.read_csv(path,sep=";")

# %%
data = df.iloc[:-1,1:].values
data = np.transpose(data)

# %%
total = df.iloc[-1][1:].values
columns = df.columns[1:]
print("Ortalama:",np.mean(total))
print("integer ortalama:",np.average(total))
print("Median:",np.median(total))
print("açıklık:",np.ptp(total))
print("Standart Sapma:",np.std(total))

# %%
plt.scatter(columns,total)
plt.title('Graph')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
