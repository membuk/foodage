# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\kekec\AppData\Local\Temp\ipykernel_7232\3845049016.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
path = "Veriler.csv"
df = pd.read_csv(path,sep=";")
data = df.iloc[:-1,1:].values
data = np.transpose(data)
total = df.iloc[-1][1:].values

# %%
X_train, X_test, y_train, y_test = train_test_split(data, total, test_size = 1/5, random_state = 123, shuffle=True)
print(X_train.shape)
model = LinearRegression()
model.fit(X_train, y_train)
predict = model.predict(X_test)
print("Pre \t","Real \t","gap")
for i in range(len(X_test)):
  print(int(predict[i]),"\t",y_test[i],"\t",abs(int(predict[i])-y_test[i]))
# Out:
# (22, 25)
# Pre 	 Real 	 gap
# 400 	 413 	 13
# 382 	 380 	 2
# 413 	 403 	 10
# 387 	 390 	 3
# 372 	 364 	 8
# 372 	 374 	 2

# %%
coefs = model.coef_
intercept = model.intercept_
print(coefs,intercept)
print(model.get_params())
# Out:
# [  0.52916596  -3.36994713   2.16800273   6.          -0.27230087
#    9.42077435 -14.1193928    9.42077435  -6.88615043   6.00972199
#   -3.78850418   8.4403036    0.41855705   6.61384957   7.17354597
#    0.67354597  -8.47569504  -5.48055603   6.00972199 -16.
#   13.20706123  -8.47569504   0.           8.4403036   14.        ] 380.9513900733413
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.score(X_test,y_test)
# Out:
# 0.7889208344670834
